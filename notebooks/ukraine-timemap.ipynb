# %% [markdown]
# # 🇺🇦 Ukraine timemap sandbox
#
# https://github.com/kamangir/blue-geo/blob/main/blue_geo/.abcli/ukraine-timemap/README.md

# %%
import os
os.environ["abcli_path_bash"] = "{}/git/awesome-bash-cli/bash".format(os.getenv("HOME"))

# %%
from abcli import fullname
from abcli import string
from abcli.modules import objects
from blue_geo import NAME, VERSION
from blue_geo.notebooks import show_on_map
from blue_geo.ukraine_timemap.functions import ingest
from blue_geo.logger import logger

logger.info(f"{NAME}-{VERSION}.{fullname()}, built on {string.pretty_date()}")
# Out:
# 🌐  blue_geo-4.151.1.abcli-9.184.1, built on 26 July 2024, 18:18:52

# %%
object_name = f"ukraine-timemap-{string.timestamp()}"
object_path = objects.object_path(object_name)

# %% [markdown]
# ---

# %%
success, gdf = ingest(object_name)
assert success
# Out:
# 🌐  blue_geo.ukraine_timemap.ingest -> ukraine-timemap-2024-07-26-18-18-52-44407
# :: abcli.file: https://bellingcat-embeds.ams3.cdn.digitaloceanspaces.com/production/ukr/timemap/api.json -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.json
# 🌐  1,881 event(s) ingested from the api.
# 🌐  1,881 event(s) -ingested-> gdf.
# 🌐  609 day(s) of events, starting 2022-02-24, until 2024-07-11.
# :: figure -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.png
# :: save_geojson: 1,881 row(s) -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.geojson
# :: save_yaml: description, created_by, creation_date, api_count, ingested_count, failure_count, range -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-26-18-18-52-44407/metadata.yaml.

# %%
gdf.head()
# Out:
#                     geometry  \
# 0  POINT (37.71513 49.59014)
# 1  POINT (32.64453 46.65170)
# 7  POINT (30.58967 50.44920)
# 8  POINT (30.48161 50.45101)
# 4  POINT (30.47152 50.46440)
#
#                                              sources      id  \
# 0                             src2, src3, src4, src5  NN6E8W
# 1                      src6, src7, src8, src9, src10  0JNOJI
# 7                  src23, src24, src25, src26, src27  WAO0E3
# 8  src28, src29, src30, src31, src32, src33, src3...  M5DZBE
# 4                                              src17  AS54HB
#
#                                          description        date  \
# 0  Four people injured after a reported FAB-500 h...  2024/07/11
# 1  Shelling of a residential area; one of the fir...  2024/07/11
# 7  Hospital damaged, at least four people reporte...  2024/07/08
# 8  Heavy damage to the children's hospital "Okhma...  2024/07/08
# 4  Several cruise missiles hit a residential area...  2024/07/08
#
#                      location graphic        associations   time
# 0  Hlushkivka, Kharkiv region   FALSE          asc1, asc2  00:00
# 1                     Kherson   FALSE    asc3, asc4, asc5  00:00
# 7                        Kyiv    TRUE         asc11, asc6  00:00
# 8                        Kyiv    TRUE  asc11, asc12, asc8  00:00
# 4                        Kyiv   FALSE          asc3, asc8  00:00

# %%
show_on_map(gdf, zoom_start=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ebe28744b62287aa0b10e46869c50cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ebe28744b62287aa0b10e46869c50cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ebe28744b62287aa0b10e46869c50cb = L.map(
#                 &quot;map_9ebe28744b62287aa0b10e46869c50cb&quot;,
#                 {
#                     center: [48.65098690074705, 34.8952695891142],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fe4b8231c9c00859f02f839925fa61c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0fe4b8231c9c00859f02f839925fa61c.addTo(map_9ebe28744b62287aa0b10e46869c50cb);
#
#
#
#         function geo_json_5437997cef4d72b45f051ae6ff9bf2d1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5437997cef4d72b45f051ae6ff9bf2d1 = L.geoJson(null, {
#                 onEachFeature: geo_json_5437997cef4d72b45f051ae6ff9bf2d1_onEachFeature,
#
#         });
#
#         function geo_json_5437997cef4d72b45f051ae6ff9bf2d1_add (data) {
#             geo_json_5437997cef4d72b45f051ae6ff9bf2d1
#                 .addData(data);
#         }
#             geo_json_5437997cef4d72b45f051ae6ff9bf2d1_add({&quot;bbox&quot;: [0.000159, -0.000752, 39.850842, 55.751014], &quot;features&quot;: [{&quot;bbox&quot;: [37.715133, 49.590138, 37.715133, 49.590138], &quot;geometry&quot;: {&quot;coordinates&quot;: [37.715133, 49.590138], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc1, asc2&quot;, &quot;date&quot;: &quot;2024/07/11&quot;, &quot;description&quot;: &quot;Four people injured after a reported FAB-500 hits a farming enterprise.&quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;NN6E8W&quot;, &quot;location&quot;: &quot;Hlushkivka, Kharkiv region&quot;, &quot;sources&quot;: &quot;src2, src3, src4, src5&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [32.64453, 46.651699, 32.64453, 46.651699], &quot;geometry&quot;: {&quot;coordinates&quot;: [32.64453, 46.651699], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc3, asc4, asc5&quot;, &quot;date&quot;: &quot;2024/07/11&quot;, &quot;description&quot;: &quot;Shelling of a residential area; one of the first responders injured in a repeated shelling.&quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;0JNOJI&quot;, &quot;location&quot;: &quot;Kherson&quot;, &quot;sources&quot;: &quot;src6, src7, src8, src9, src10&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.589668, 50.449199, 30.589668, 50.449199], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.589668, 50.449199], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc11, asc6&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;Hospital damaged, at least four people reported killed and several injured.&quot;, &quot;graphic&quot;: &quot;TRUE&quot;, &quot;id&quot;: &quot;WAO0E3&quot;, &quot;location&quot;: &quot;Kyiv&quot;, &quot;sources&quot;: &quot;src23, src24, src25, src26, src27&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.481609, 50.451011, 30.481609, 50.451011], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.481609, 50.451011], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;8&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc11, asc12, asc8&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;Heavy damage to the children\u0027s hospital \&quot;Okhmatdyt\&quot; as a result of the massive missile attack.&quot;, &quot;graphic&quot;: &quot;TRUE&quot;, &quot;id&quot;: &quot;M5DZBE&quot;, &quot;location&quot;: &quot;Kyiv&quot;, &quot;sources&quot;: &quot;src28, src29, src30, src31, src32, src33, src34, src35&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.471518, 50.464405, 30.471518, 50.464405], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.471518, 50.464405], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc3, asc8&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;Several cruise missiles hit a residential area in central Kyiv.&quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;AS54HB&quot;, &quot;location&quot;: &quot;Kyiv&quot;, &quot;sources&quot;: &quot;src17&quot;, &quot;time&quot;: &quo

# %% [markdown]
# ---

# %%
# %%bash -s $object_name
# source ~/git/awesome-bash-cli/abcli/.abcli/abcli.sh in_notebook
#
# object_name=$1
#
# abcli select $object_name
# abcli tag set . built_by_notebook
# abcli upload
# Out:
# 🌀 blueness-3.66.1
# 🌀 blue_options-4.35.1
# 📜 awesome-bash-cli: .env: 24 env var(s)
# 📜 awesome-bash-cli: abcli/config.env: 13 env var(s)
# 🔋 gpu: not found.
# 🚀 abcli-9.184.1.current
# 📂 object :: ukraine-timemap-2024-07-26-18-18-52-44407
# :: ukraine-timemap-2024-07-26-18-18-52-44407 += #built_by_notebook.
# confirmed: ukraine-timemap-2024-07-26-18-18-52-44407 does not exist.
# ukraine-timemap-2024-07-26-18-18-52-44407 open upload started.
# upload: ./abcli.log to s3://kamangir/bolt/ukraine-timemap-2024-07-26-18-18-52-44407/abcli.log
# upload: ./metadata.yaml to s3://kamangir/bolt/ukraine-timemap-2024-07-26-18-18-52-44407/metadata.yaml
# upload: ./ukraine_timemap.png to s3://kamangir/bolt/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.png
# upload: ./ukraine_timemap.geojson to s3://kamangir/bolt/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.geojson
# upload: ./ukraine_timemap.json to s3://kamangir/bolt/ukraine-timemap-2024-07-26-18-18-52-44407/ukraine_timemap.json
# :: ukraine-timemap-2024-07-26-18-18-52-44407 += #open.

# %%
# END
