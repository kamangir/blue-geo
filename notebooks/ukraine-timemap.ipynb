# %% [markdown]
# # 🇺🇦 Ukraine timemap sandbox
#
# https://github.com/kamangir/blue-geo/blob/main/blue_geo/.abcli/ukraine-timemap/README.md

# %%
import os
os.environ["abcli_path_bash"] = "{}/git/awesome-bash-cli/bash".format(os.getenv("HOME"))

# %%
from abcli import fullname
from abcli import string
from abcli.modules import objects
from blue_geo import VERSION
from blue_geo.notebooks import show_on_map
from blue_geo.ukraine_timemap import NAME
from blue_geo.ukraine_timemap.functions import ingest
from blue_geo.logger import logger

logger.info(f"{NAME}-{VERSION}.{fullname()}, built on {string.pretty_date()}")
# Out:
# 🌐  blue_geo.ukraine_timemap-4.51.1.abcli-9.163.1, built on 16 July 2024, 20:29:55

# %%
object_name = f"ukraine-timemap-{string.timestamp()}"
object_path = objects.object_path(object_name)

# %% [markdown]
# ---

# %%
success, gdf = ingest(object_name)
assert success
# Out:
# 🌐  blue_geo.ukraine_timemap.ingest -> ukraine-timemap-2024-07-16-20-29-55-41559
# :: abcli.file: https://bellingcat-embeds.ams3.cdn.digitaloceanspaces.com/production/ukr/timemap/api.json -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.json
# 🌐  1,869 event(s) ingested from the api.
# 🌐  1,869 event(s) -ingested-> gdf.
# 🌐  608 day(s) of events, starting 2022-02-24, until 2024-07-08.
# :: figure -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.png
# :: save_geojson: 1,869 row(s) -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.geojson
# :: save_yaml: description, created_by, creation_date, api_count, ingested_count, failure_count, range -> /Users/kamangir/storage/abcli/ukraine-timemap-2024-07-16-20-29-55-41559/metadata.yaml.

# %%
gdf.head()
# Out:
#                     geometry  \
# 0  POINT (33.55324 48.15886)
# 2  POINT (30.48161 50.45101)
# 1  POINT (30.58967 50.44920)
# 3  POINT (36.29000 50.04012)
# 5  POINT (35.06569 48.42940)
#
#                                              sources      id  \
# 0                             src2, src3, src4, src5  3TVPSL
# 2  src11, src12, src13, src14, src15, src16, src1...  M5DZBE
# 1                      src6, src7, src8, src9, src10  WAO0E3
# 3                         src19, src20, src21, src22  ROCH0Y
# 5                                src27, src28, src29  0SLHCB
#
#                                          description        date  \
# 0  At least ten people reported killed and thirty...  2024/07/08
# 2  Heavy damage to the children's hospital "Okhma...  2024/07/08
# 1  Hospital damaged, at least four people reporte...  2024/07/08
# 3  Kab hitting civilian street in kyivsky distric...  2024/07/03
# 5  Aftermath of the night attack reportedly with ...  2024/07/01
#
#                              location graphic      associations   time
# 0  Kryvyi Rih (Dnipropetrovsk oblast)   FALSE              asc1  00:00
# 2                                Kyiv    TRUE  asc2, asc4, asc5  00:00
# 1                                Kyiv    TRUE        asc2, asc3  00:00
# 3          Kharkiv (Kyivsky district)   FALSE        asc6, asc7  00:00
# 5                              Dnipro   FALSE        asc6, asc4  00:00

# %%
show_on_map(gdf, zoom_start=5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d34f3f38b43d7bc06f07d34f8a6a92b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d34f3f38b43d7bc06f07d34f8a6a92b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d34f3f38b43d7bc06f07d34f8a6a92b = L.map(
#                 &quot;map_8d34f3f38b43d7bc06f07d34f8a6a92b&quot;,
#                 {
#                     center: [48.64897275725021, 34.90226200966702],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23e9614ea69419debbb05202f7278c3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_23e9614ea69419debbb05202f7278c3f.addTo(map_8d34f3f38b43d7bc06f07d34f8a6a92b);
#
#
#
#         function geo_json_043be2b896f295933d1b56b108308e5a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_043be2b896f295933d1b56b108308e5a = L.geoJson(null, {
#                 onEachFeature: geo_json_043be2b896f295933d1b56b108308e5a_onEachFeature,
#
#         });
#
#         function geo_json_043be2b896f295933d1b56b108308e5a_add (data) {
#             geo_json_043be2b896f295933d1b56b108308e5a
#                 .addData(data);
#         }
#             geo_json_043be2b896f295933d1b56b108308e5a_add({&quot;bbox&quot;: [-0.000366, -5.5e-05, 39.850842, 55.751014], &quot;features&quot;: [{&quot;bbox&quot;: [33.553243, 48.158865, 33.553243, 48.158865], &quot;geometry&quot;: {&quot;coordinates&quot;: [33.553243, 48.158865], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc1&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;At least ten people reported killed and thirty injured as a result of the strike at the office building of the mining enterpise.&quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;3TVPSL&quot;, &quot;location&quot;: &quot;Kryvyi Rih (Dnipropetrovsk oblast)&quot;, &quot;sources&quot;: &quot;src2, src3, src4, src5&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.481609, 50.451011, 30.481609, 50.451011], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.481609, 50.451011], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc2, asc4, asc5&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;Heavy damage to the children\u0027s hospital \&quot;Okhmatdyt\&quot; as a result of the massive missile attack.&quot;, &quot;graphic&quot;: &quot;TRUE&quot;, &quot;id&quot;: &quot;M5DZBE&quot;, &quot;location&quot;: &quot;Kyiv&quot;, &quot;sources&quot;: &quot;src11, src12, src13, src14, src15, src16, src17, src18&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [30.589668, 50.449199, 30.589668, 50.449199], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.589668, 50.449199], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc2, asc3&quot;, &quot;date&quot;: &quot;2024/07/08&quot;, &quot;description&quot;: &quot;Hospital damaged, at least four people reported killed and several injured.&quot;, &quot;graphic&quot;: &quot;TRUE&quot;, &quot;id&quot;: &quot;WAO0E3&quot;, &quot;location&quot;: &quot;Kyiv&quot;, &quot;sources&quot;: &quot;src6, src7, src8, src9, src10&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [36.290004, 50.040124, 36.290004, 50.040124], &quot;geometry&quot;: {&quot;coordinates&quot;: [36.290004, 50.040124], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc6, asc7&quot;, &quot;date&quot;: &quot;2024/07/03&quot;, &quot;description&quot;: &quot;Kab hitting civilian street in kyivsky district of Kharkov&quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;ROCH0Y&quot;, &quot;location&quot;: &quot;Kharkiv (Kyivsky district)&quot;, &quot;sources&quot;: &quot;src19, src20, src21, src22&quot;, &quot;time&quot;: &quot;00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [35.06569, 48.429402, 35.06569, 48.429402], &quot;geometry&quot;: {&quot;coordinates&quot;: [35.06569, 48.429402], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;associations&quot;: &quot;asc6, asc4&quot;, &quot;date&quot;: &quot;2024/07/01&quot;, &quot;description&quot;: &quot;Aftermath of the night attack reportedly with ballistic missiles. At least seven people injured including minors. &quot;, &quot;graphic&quot;: &quot;FALSE&quot;, &quot;id&quot;: &quot;0SLHCB&quot;, &quot;location&quot;:

# %% [markdown]
# ---

# %%
# %%bash -s $object_name
# source ~/git/awesome-bash-cli/abcli/.abcli/abcli.sh in_notebook
#
# object_name=$1
#
# abcli select $object_name
# abcli tag set . built_by_notebook
# abcli upload
# Out:
# 🌀 blueness-3.64.1
# 🌀 blue_options-4.35.1
# 📜 awesome-bash-cli: .env: 24 env var(s)
# 📜 awesome-bash-cli: abcli/config.env: 13 env var(s)
# 🔋 gpu: not found.
# 🚀 abcli-9.163.1.current
# 📂 object :: ukraine-timemap-2024-07-16-20-29-55-41559
# :: ukraine-timemap-2024-07-16-20-29-55-41559 += #built_by_notebook.
# confirmed: ukraine-timemap-2024-07-16-20-29-55-41559 does not exist.
# ukraine-timemap-2024-07-16-20-29-55-41559 open upload started.
# upload: ./metadata.yaml to s3://kamangir/bolt/ukraine-timemap-2024-07-16-20-29-55-41559/metadata.yaml
# upload: ./abcli.log to s3://kamangir/bolt/ukraine-timemap-2024-07-16-20-29-55-41559/abcli.log
# upload: ./ukraine_timemap.png to s3://kamangir/bolt/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.png
# upload: ./ukraine_timemap.json to s3://kamangir/bolt/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.json
# upload: ./ukraine_timemap.geojson to s3://kamangir/bolt/ukraine-timemap-2024-07-16-20-29-55-41559/ukraine_timemap.geojson
# :: ukraine-timemap-2024-07-16-20-29-55-41559 += #open.

# %%
# END
